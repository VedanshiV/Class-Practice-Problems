# %%
# question 1
numbers = (10,20,30,40,50,60,70,80,90)
print("tuple:", numbers)
print("4th element from first:", numbers[3])
print("4th element from last:", numbers[-4])
# Out:
# tuple: (10, 20, 30, 40, 50, 60, 70, 80, 90)
# 4th element from first: 40
# 4th element from last: 60

# %%
# question 2
numbers = (10,20,30,40,50)
element = int(input("enter element to scearch: "))
if element in numbers:
    print("element exists in tuple")
else:
    print("element does not exist in the tuple")
# Out:
# enter element to scearch:  20
# element exists in tuple

# %%
# question 3
numbers_list = [10,20,30,40,50]
numbers_tuple = tuple(numbers_list)
print("list:", numbers_list)
print("tuple:", numbers_tuple)
# Out:
# list: [10, 20, 30, 40, 50]
# tuple: (10, 20, 30, 40, 50)

# %%
# question 4
numbers = (10,20,30,40,50)
element = int(input("enter element: "))
if element in numbers:
    print("index of elements:", numbers.index(element))
else:
    print("element not found")
# Out:
# enter element:  46
# element not found

# %%
# question 5
numbers = [(10,20,40),(40,50,60),(70,80,90)]
new_list = []
for tup in numbers:
    new_tup = tup[:-1] + (100,)
    new_list.append(new_tup)
print("original list:", numbers)
print("updated list:", new_list)
# Out:
# original list: [(10, 20, 40), (40, 50, 60), (70, 80, 90)]
# updated list: [(10, 20, 100), (40, 50, 100), (70, 80, 100)]

# %%
# question 6
numbers = (25,10,45,5,60,30)
maximum = max(numbers)
minimum = min(numbers)
print("tuple: ", numbers)
print("maximum element:", maximum)
print("minimum element:", minimum)
# Out:
# tuple:  (25, 10, 45, 5, 60, 30)
# maximum element: 60
# minimum element: 5

# %%
# question 7
numbers = (10,20,30,40,50)
new_tuple = (numbers[-1],) + numbers[1:-1] + (numbers[0],)
print("original tuple: ", numbers)
print("tuple after swapping: ", new_tuple)
# Out:
# original tuple:  (10, 20, 30, 40, 50)
# tuple after swapping:  (50, 20, 30, 40, 10)
